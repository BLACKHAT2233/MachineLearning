# %% [markdown]
# # Sanket  Mhaske

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("movie_metadata.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b637d46c4070> in <cell line: 1>()
# ----> 1 data = pd.read_csv("movie_metadata.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
data

# %%
data.shape

# %% [markdown]
# # Duplicated

# %%
data.duplicated().sum()

# %%
data=data.drop_duplicates()

# %%
data.duplicated().sum()

# %%
data.shape

# %% [markdown]
# # -----------------checking null---------------------

# %%
data.isna().sum()

# %%
df=data.dropna()

# %%
df.shape

# %%
df.isnull().sum()

# %%
data.shape

# %%
df.shape

# %% [markdown]
# # Single Colume Drop

# %%
df=df.drop('director_name',axis='columns')
df

# %% [markdown]
# # Multiple Columes Drop

# %%
df = df.drop(['color','gross'],axis='columns')
df

# %% [markdown]
# # category

# %%
df['country']=df['country'].astype('category')
df['country']=df['country'].cat.codes

# %%
df

# %% [markdown]
# # mean of country

# %%
mean = df.country.median()
mean

# %%
data

# %% [markdown]
# # Replace Nan with mean

# %%
mean = data.gross.mean()
mean

# %%
data.gross

# %%
data.gross = data.gross.fillna(data.gross.mean())
data

# %% [markdown]
# # Replaces

# %%
data['color']=data['color'].fillna(0)
data

# %%
data.num_critic_for_reviews=data.num_critic_for_reviews.fillna(data.num_critic_for_reviews.mean())
data

# %%
data['color'] = data['color'].str.replace('Color', 'I love you ')
data
